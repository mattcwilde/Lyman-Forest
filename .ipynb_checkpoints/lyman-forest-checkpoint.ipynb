# %% [markdown]
# #  Spectrum of the Lyman-n forest.
#
# Data: The input data are files each representing a skewer through a 25Mpc co-moving simulation box.
#
# I am going to add the Lyman-n series to each skewer then, eventually, add $\sim 50$ skewers together to get a simulated quasar spectrum.

# %%
# %matplotlib inline
from __future__ import division
import matplotlib.pyplot as plt
import matplotlib as mpl
from glob import glob
import numpy as np
import astropy.constants as const
import astropy.units as u
plt.rc('font', family='serif', size=15)

import pandas as pd

# path to the data, for both computers its in ~/Data:
path = '/Users/mwilde/Data/'

#use the pretty LaTeX fonts
mpl.rcParams.update({'text.usetex': True})

# %% [markdown]
# #### define constants:

# %%
# c = const.c.cgs.value # speed of light in cm/s
c = const.c.to(u.km / u.s).value # km/s
R_h = const.Ryd.to(1 / u.Angstrom).value # Rydberg constant in 1 /angstroms

# %% [markdown]
# #### Flux:
# $F = e^{-\tau}$

# %%
def flux(t):
    """A function to convert tau to flux using the relation
    
    I = I(0)exp(-tau)
    
    or if S_v = 1
    
    I = I(0)exp(-tau) + (1 - exp(-tau))
    with I(0) = 0.
    
    """
    return np.exp(-t)

# %% [markdown]
# #### Oscillator strength or $g-f$ value for the Lyman series:
# $gf_{1n} = \frac{2^9 n^5(n-1)^{2n-4}}{3(n+1)^{2n+4}}$

# %%
def gf_1n(nn):
    """ A function to calculate the oscillator strengths of of the Lyman series (n'=1).
        
        Reference: RL equation 10.46 (p.281)
    """
    if nn == 1:
        gf = 1.0
    elif nn == 0:
        gf = 1.0
    else:
        gf = (2**9 * nn**5 * (nn-1)**(2*nn-4)) / (3*(nn+1)**(2*nn+4))
    return gf

# %% [markdown]
# #### Convert velocity, $v$ into observed wavelength:
# $\lambda_{obs}(1+z) = \lambda_0(1 - \frac{v}{c})$

# %%
def lam_obs(vv,lam_0):
    """This function takes as input the velocity in km/s and the emitted wavelength 
    as well as the redshift.
    
    returns the wavelength in the observers frame angstroms."""
    return lam_0*(1 + vv/c) # vv from km/s, c in km/s

# %% [markdown]
# #### Open the first few files:
#
# Format of the data
#
# velocity [km/s], tau_HILya, tau_HeI584, tau_HeIILya, nHI [cm^-3], nHeII [cm^-3], Delta_b, T [K], xpos [Mpc/h], vpec [km/sec]

# %%
! head /Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0000.dat
# Out:
# #Redshift = 2.45e+00 Box = 2.50e+04 [kpc/h] VelScale = 2.53e+03 [km/s]
# #x = 3.01e-01 y = 7.85e-01
# #velocity [km/s], tau_HILya, tau_HeI584, tau_HeIILya, nHI [cm^-3], nHeII [cm^-3], Delta_b, T [K], xpos [Mpc/h], vpec [km/sec]
# 0.000e+00 1.086e-01 2.934e-03 2.724e+00 8.680e-12 8.680e-10 2.980e+00 1.721e+04 7.558e+03 -8.706e+01
# 8.441e-01 1.120e-01 3.089e-03 2.868e+00 8.913e-12 8.913e-10 3.001e+00 1.721e+04 7.567e+03 -8.703e+01
# 1.688e+00 1.155e-01 3.236e-03 3.005e+00 9.094e-12 9.094e-10 3.004e+00 1.721e+04 7.575e+03 -8.682e+01
# 2.532e+00 1.189e-01 3.373e-03 3.131e+00 9.271e-12 9.271e-10 3.005e+00 1.719e+04 7.583e+03 -8.639e+01
# 3.377e+00 1.224e-01 3.496e-03 3.246e+00 9.583e-12 9.583e-10 3.057e+00 1.716e+04 7.592e+03 -8.582e+01
# 4.221e+00 1.258e-01 3.606e-03 3.348e+00 1.000e-11 1.000e-09 3.157e+00 1.711e+04 7.600e+03 -8.524e+01
# 5.065e+00 1.292e-01 3.700e-03 3.436e+00 1.038e-11 1.038e-09 3.262e+00 1.705e+04 7.608e+03 -8.476e+01

# %%
infile = path+'sim_data/z2.45/spec_xHeII1_015_mt_line0000.dat'
v, tau_HILya, tau_HeI584, tau_HeIILya, nHI, nHeII, Delta_b, T, xpos, vpec = np.loadtxt(infile,unpack=True)

# %%
pd_read_files(file_list)
# Out:
# array([], dtype=float64)

# %%
# Out:
# 1 loops, best of 3: 12.5 s per loop

# %% [markdown]
# #### What does the data look like?

# %%
# plt.plot(v,tau_HILya)
plt.plot(lam_obs(v,700), flux(tau_HILya))

print lam_obs(v,700).min() - lam_obs(v,700).max()
# Out:
# -5.91209002329

# %% [markdown]
# Compute $N_{HI}(x)$

# %%
q0 = -0.55
proper_d = (v/70.)*(1 - (1+q0)/2 * v/c)

NHI = nHI*proper_d

plt.figure(figsize=(12,8))
plt.semilogy(proper_d, NHI, label=r'$N_{HI}$')
#plt.semilogy(v/70., nHI)
plt.semilogy(proper_d, nHI, label=r'$n_{HI}$')
plt.xlabel('Mpc')
plt.ylabel(r'$[cm^{-3}]$')
plt.legend()
plt.show()

print proper_d
# Out:
# [  0.00000000e+00   1.20585638e-02   2.41142552e-02 ...,   3.60742286e+01
#    3.60884600e+01   3.61026915e+01]

# %%
def d_p(wave):
    """ compute the proper distance a wave travels to redshift under Lyman limit
        
        returns distance in [Mpc]
    """
    
    #define constants
    c = const.c.to(u.km / u.s).value
    H0 = 70.0
    #H0 = 69.6
    q0 = -0.55
    #q0 = 0.286
    z = (wave/912. - 1)
    z = (912/wave - 1)
    z = 2.45
    
    d = (c/H0)*z*(1 - (1+q0)*z/2)
    return d

# %%
d_p(700)

# %% [markdown]
# #### Add the Lyman series lines for first skewer.

# %% [markdown]
# $\tau_{1n} \rightarrow \frac{f_n}{f_{Ly\alpha}} \tau$ and $f_{Ly\alpha} = gf_{12}$ where $gf_{12}$ is the oscillator strength for the $n = 1$ to $n = 2$ transition.

# %% [markdown]
# take the $\tau_{Ly\alpha}$ from the file and make a new array with added levels:

# %%
f_Lya = gf_1n(2) # define a variable for Lyman alpha oscillator strength
f_1n = np.array([gf_1n(n)/f_Lya for n in range(2,1000)]) 
# make an array of the oscillator strengths and convert to opacity

# %% [markdown]
# #### Get emitted wavelengths:
#
#
# $ \frac{1}{\lambda} = Ry(1-\frac{1}{n^2})$

# %%
def lyman_lambda(nmax):
    return (R_h*(1 - (1/nmax**2)))**-1

# %% [markdown]
# #### Make a plot of the Lyman-n series for one skewer.

# %%
plt.figure(figsize=(12,6))
plt.gca().invert_xaxis()

for i in range(2,100):
    plt.plot(lam_obs(v,lyman_lambda(i)), flux(tau_HILya*f_1n[i-2]))

# %% [markdown]
# $\lambda_{obs}(1+z) = \lambda_0(1 + \frac{v_1+v_2+...+v_n}{c})$

# %% [markdown]
# # Make an average forest for 2000 different forests of length = 50
#
# ### Each box is then 1.25 Gpc/h

# %%
box_size = 2.50e+04*u.kpc # [kpc/h]
num_boxes = 50
print (box_size*num_boxes).to(u.Gpc),"/h"
# Out:
# 1.25 Gpc /h

# %% [markdown]
# Read in each file and make an list of the $\tau_{HILy\alpha}$ arrays from each file:

# %%
#step size to bin the tau files to run faster
step = 100

# %%
! head ../../../Data/sim_data/z2.45/spec_xHeII1_015_mt_line0000.dat
# Out:
# #Redshift = 2.45e+00 Box = 2.50e+04 [kpc/h] VelScale = 2.53e+03 [km/s]
# #x = 3.01e-01 y = 7.85e-01
# #velocity [km/s], tau_HILya, tau_HeI584, tau_HeIILya, nHI [cm^-3], nHeII [cm^-3], Delta_b, T [K], xpos [Mpc/h], vpec [km/sec]
# 0.000e+00 1.086e-01 2.934e-03 2.724e+00 8.680e-12 8.680e-10 2.980e+00 1.721e+04 7.558e+03 -8.706e+01
# 8.441e-01 1.120e-01 3.089e-03 2.868e+00 8.913e-12 8.913e-10 3.001e+00 1.721e+04 7.567e+03 -8.703e+01
# 1.688e+00 1.155e-01 3.236e-03 3.005e+00 9.094e-12 9.094e-10 3.004e+00 1.721e+04 7.575e+03 -8.682e+01
# 2.532e+00 1.189e-01 3.373e-03 3.131e+00 9.271e-12 9.271e-10 3.005e+00 1.719e+04 7.583e+03 -8.639e+01
# 3.377e+00 1.224e-01 3.496e-03 3.246e+00 9.583e-12 9.583e-10 3.057e+00 1.716e+04 7.592e+03 -8.582e+01
# 4.221e+00 1.258e-01 3.606e-03 3.348e+00 1.000e-11 1.000e-09 3.157e+00 1.711e+04 7.600e+03 -8.524e+01
# 5.065e+00 1.292e-01 3.700e-03 3.436e+00 1.038e-11 1.038e-09 3.262e+00 1.705e+04 7.608e+03 -8.476e+01

# %%
test_file = "../../../Data/sim_data/z2.45/spec_xHeII1_015_mt_line0000.dat"
# pd.read_table(test_file, header=2, delimiter=' ')
names = ["velocity [km/s]", "tau_HILya", "tau_HeI584", "tau_HeIILya", 
         "nHI [cm^-3]", "nHeII [cm^-3]", "Delta_b", "T [K]", "xpos [Mpc/h]", "vpec [km/sec]"]
pd.read_table(test_file, header=0, names=names, delimiter=' ', comment='#')[:10]
# Out:
#    velocity [km/s]  tau_HILya  tau_HeI584  tau_HeIILya   nHI [cm^-3]  \
# 0           0.8441     0.1120    0.003089        2.868  8.913000e-12
# 1           1.6880     0.1155    0.003236        3.005  9.094000e-12
# 2           2.5320     0.1189    0.003373        3.131  9.271000e-12
# 3           3.3770     0.1224    0.003496        3.246  9.583000e-12
# 4           4.2210     0.1258    0.003606        3.348  1.000000e-11
# 5           5.0650     0.1292    0.003700        3.436  1.038000e-11
# 6           5.9090     0.1326    0.003781        3.510  1.067000e-11
# 7           6.7530     0.1360    0.003848        3.572  1.071000e-11
# 8           7.5970     0.1393    0.003903        3.624  1.048000e-11
# 9           8.4410     0.1426    0.003950        3.668  1.005000e-11
#
#    nHeII [cm^-3]  Delta_b  T [K]  xpos [Mpc/h]  vpec [km/sec]
# 0   8.913000e-10    3.001  17210          7567         -87.03
# 1   9.094000e-10    3.004  17210          7575         -86.82
# 2   9.271000e-10    3.005  17190          7583         -86.39
# 3   9.583000e-10    3.057  17160          7592         -85.82
# 4   1.000000e-09    3.157  17110          7600         -85.24
# 5   1.038000e-09    3.262  17050          7608         -84.76
# 6   1.067000e-09    3.352  16990          7617         -84.46
# 7   1.071000e-09    3.368  16930          7625         -84.25
# 8   1.048000e-09    3.304  16870          7633         -84.03
# 9   1.005000e-09    3.184  16780          7642         -83.72

# %% [markdown]
# ## I know `np.loadtxt` can be really slow. I want to test out a better method.
# - Python with lists takes ~1 minute
# - stacking np arrays is just as slow
# - Pandas is faster by a factor of ~5
# - Julia is faster by a fact ~10
# - HDF5 = ?
# - Julia to single file then ... ?

# %%
file_list = glob(path+'sim_data/z2.45/spec_xHeII1_015_mt_line*.dat')
def py_read_files(file_list):
    step = 10
    t_list = []
    # nHI = []
    # file_list = glob(path+'sim_data/z2.45/spec_xHeII1_015_mt_line*.dat')
    for f in file_list:
        v,t,c1,c2,n,c4,c5,c6,c7,c8 = np.loadtxt(f, unpack=True)
        t_list.append(t)
        # nHI.append(n)
    # diffv = v[1] - v[0]
    return t_list

# %%
file_list = glob(path+'sim_data/z2.45/spec_xHeII1_015_mt_line*.dat')
def np_read_files(file_list):
    t_array = np.zeros(0)
    for f in file_list:
        v,t,c1,c2,n,c4,c5,c6,c7,c8 = np.loadtxt(f, unpack=True)
        np.hstack((t_array, t))
    return t_array

# %%
file_list = glob(path+'sim_data/z2.45/spec_xHeII1_015_mt_line*.dat')
def pd_read_files(infile):
    t_array = np.zeros(0)
    for f in infile:
        df = pd.read_table(f, header=None, comment='#', delimiter=' ')
        # n = df.values[4]
        np.hstack((t_array, df.values[1]))
    return t_array

# %%
# %timeit df = pd.concat((pd.read_table(f, header=None, comment='#', delimiter=' ',index_col=False) for f in file_list))
# Out:
# 1 loops, best of 3: 12.6 s per loop

# %%
# %timeit py_read_files(file_list)
# Out:
# 1 loops, best of 3: 1min 8s per loop

# %%
# %timeit pd_read_files(file_list)
# Out:
# 1 loops, best of 3: 12.6 s per loop

# %%
# %timeit np_read_files(file_list)
# Out:
# 1 loops, best of 3: 1min 7s per loop

# %%
df
# Out:
#               0        1         2       3             4             5      6  \
# 0        0.0000  0.01836  0.000471  0.4376  1.482000e-11  1.482000e-09  4.804
# 1        0.8441  0.01846  0.000471  0.4370  1.432000e-11  1.432000e-09  4.743
# 2        1.6880  0.01856  0.000471  0.4376  1.356000e-11  1.356000e-09  4.567
# 3        2.5320  0.01866  0.000474  0.4396  1.213000e-11  1.213000e-09  4.159
# 4        3.3770  0.01878  0.000477  0.4432  1.028000e-11  1.028000e-09  3.625
# 5        4.2210  0.01889  0.000483  0.4483  8.632000e-12  8.632000e-10  3.174
# 6        5.0650  0.01901  0.000490  0.4549  7.657000e-12  7.657000e-10  2.960
# 7        5.9090  0.01914  0.000499  0.4629  7.400000e-12  7.400000e-10  2.983
# 8        6.7530  0.01926  0.000508  0.4718  7.523000e-12  7.523000e-10  3.105
# 9        7.5970  0.01938  0.000518  0.4813  7.526000e-12  7.526000e-10  3.146
# 10       8.4410  0.01951  0.000529  0.4910  7.178000e-12  7.178000e-10  3.031
# 2985  2520.0000  0.01799  0.000475  0.4413  2.132000e-11  2.132000e-09  5.746
# 2986  2521.0000  0.01795  0.000476  0.4423  2.264000e-11  2.264000e-09  6.119
# 2987  2521.0000  0.01793  0.000478  0.4439  2.281000e-11  2.281000e-09  6.192
# 2988  2522.0000  0.01791  0.000480  0.4456  2.168000e-11  2.168000e-09  5.932
# 2989  2523.0000  0.01790  0.000482  0.4474  2.027000e-11  2.027000e-09  5.604
# 2990  2524.0000  0.01790  0.000483  0.4489  1.946000e-11  1.946000e-09  5.430
# 2991  2525.0000  0.01790  0.000485  0.4500  1.947000e-11  1.947000e-09  5.454
# 2992  2526.0000  0.01792  0.000485  0.4506  1.964000e-11  1.964000e-09  5.512
# 2993  2526.0000  0.01794  0.000485  0.4504  1.976000e-11  1.976000e-09  5.560
# 2994  2527.0000  0.01798  0.000484  0.4496  1.979000e-11  1.979000e-09  5.598
# 2995  2528.0000  0.01802  0.000483  0.4481  1.968000e-11  1.968000e-09  5.621
# 2996  2529.0000  0.01807  0.000480  0.4460  1.922000e-11  1.922000e-09  5.576
# 2997  2530.0000  0.01813  0.000478  0.4437  1.818000e-11  1.818000e-09  5.385
# 2998  2531.0000  0.01820  0.000475  0.4413  1.672000e-11  1.672000e-09  5.094
# 2999  2532.0000  0.01828  0.000473  0.4391  1.556000e-11  1.556000e-09  4.895
#
#           7     8      9
# 0     27990  1525 -246.7
# 1     27990  1533 -245.8
# 2     27960  1542 -245.1
# 3     27810  1550 -244.5
# 4     27460  1558 -243.7
# 5     26880  1567 -242.8
# 6     26250  1575 -241.8
# 7     25880  1583 -240.6
# 8     25790  1592 -239.4
# 9     25810  1600 -238.3
# 10    25780  1608 -237.2
# 11    25650  1617 -236.4
# 12    25430  1625 -236.0
# 13    25210  1633 -235.9
# 14    25060  1642 -236.1
# 15    24940  1650 -236.1
# 16    24770  1658 -235.8
# 17    24490  1667 -235.2
# 18    24000  1675 -234.3
# 19    23190  1683 -233.1
# 20    22110  1692 -231.5
# 21    21050  1700 -230.2
# 22    20350  1708 -229.4
# 23    20010  1717 -229.0
# 24    19750  1725 -228.7
# 25    19430  1733 -228.3
# 26    19050  1742 -227.5
# 27    18660  1750 -226.5
# 28    18330  1758 -225.2
# 29    18100  1767 -223.9
# ...     ...   ...    ...
# 2970  28850  1275 -268.5
# 2971  28850  1283 -267.9
# 2972  28840  1292 -267.3
# 2973  28880  1300 -266.7
# 2974  28960  1308 -265.8
# 2975  29010  1317 -264.7
# 2976  29070  1325 -263.7
# 2977  29220  1333 -262.9
# 2978  29470  1342 -262.2
# 2979  29800  1350 -261.5
# 2980  30070  1358 -260.8
# 2981  30270  1367 -260.2
# 2982  30420  1375 -259.6
# 2983  30640  1383 -258.9
# 2984  30950  1392 -258.1
# 2985  31260  1400 -257.3
# 2986  31370  1408 -256.4
# 2987  31220  1417 -255.4
# 2988  30790  1425 -254.4
# 2989  30150  1433 -253.3
# 2990  29490  1442 -252.5
# 2991  28930  1450 -252.2
# 2992  28520  1458 -252.1
# 2993  28240  1467 -252.1
# 2994  28080  1475 -251.8
# 2995  28060  1483 -251.3
# 2996  28100  1492 -250.6
# 2997  28110  1500 -249.8
# 2998  28060  1508 -248.9
# 2999  28010  1517 -247.8
#
# [3000 rows x 10 columns]

# %%
file_list
# Out:
# ['/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line
dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0859.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0860.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0861.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0862.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0863.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0864.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0865.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0866.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0867.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0868.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0869.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0870.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0871.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0872.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0873.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0874.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0875.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0876.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0877.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0878.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0879.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0880.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0881.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0882.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0883.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0884.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0885.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0886.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0887.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0888.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0889.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0890.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0891.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0892.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0893.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0894.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0895.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0896.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0897.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0898.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0899.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0900.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0901.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0902.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0903.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0904.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0905.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0906.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0907.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0908.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0909.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0910.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0911.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0912.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0913.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0914.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0915.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0916.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0917.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0918.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0919.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0920.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0921.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0922.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0923.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0924.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0925.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0926.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0927.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0928.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0929.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0930.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0931.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0932.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0933.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0934.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0935.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0936.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0937.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0938.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0939.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0940.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0941.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0942.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0943.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0944.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0945.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0946.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0947.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0948.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0949.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0950.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0951.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0952.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0953.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0954.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0955.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0956.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0957.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0958.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0959.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0960.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0961.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0962.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0963.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0964.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0965.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0966.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0967.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0968.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0969.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0970.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0971.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0972.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0973.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0974.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0975.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0976.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0977.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0978.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0979.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0980.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0981.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0982.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0983.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0984.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0985.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0986.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0987.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0988.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0989.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0990.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0991.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0992.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0993.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0994.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0995.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0996.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0997.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0998.dat',
#  '/Users/mwilde/Data/sim_data/z2.45/spec_xHeII1_015_mt_line0999.dat',
#  ...]

# %%
import h5py

def hdf5_read(file_list):
    for f in file_list:
        df = pd.read_table(f, header=None, comment='#', delimiter=' ')
        data = np.loadtxt(f)
        h5file = h5py.File(f[:-4]+".h5",'w')
        h5file['data'] = data
        h5file.close()

# %% [markdown]
# Initialize all the arrays to loop:

# %%
# %timeit hdf5_read(file_list)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-96-0ced6ebb79e9> in <module>()
# ----> 1 get_ipython().magic(u'timeit hdf5_read(file_list)')
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
#    2258             return result
#    2259
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1035             number = 1
#    1036             for _ in range(1, 10):
# -> 1037                 time_number = timer.timeit(number)
#    1038                 worst_tuning = max(worst_tuning, time_number / number)
#    1039                 if time_number >= 0.2:
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, number)
#     131         gc.disable()
#     132         try:
# --> 133             timing = self.inner(it, self.timer)
#     134         finally:
#     135             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-95-9abbf7f7c542> in hdf5_read(file_list)
#       4 def hdf5_read(file_list):
#       5     for f in file_list:
# ----> 6         df = pd.read_table(f, header=None, comment='#', delimiter=' ')
#       7         data = np.loadtxt(f)
#       8         h5file = h5py.File(f,'w')
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     496                     skip_blank_lines=skip_blank_lines)
#     497
# --> 498         return _read(filepath_or_buffer, kwds)
#     499
#     500     parser_f.__name__ = name
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     283         return parser
#     284
# --> 285     return parser.read()
#     286
#     287 _parser_defaults = {
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     745                 raise ValueError('skip_footer not supported for iteration')
#     746
# --> 747         ret = self._engine.read(nrows)
#     748
#     749         if self.options.get('as_recarray'):
#
# /Users/mwilde/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1195     def read(self, nrows=None):
#    1196         try:
# -> 1197             data = self._reader.read(nrows)
#    1198         except StopIteration:
#    1199             if self._first_chunk:
#
# pandas/parser.pyx in pandas.parser.TextReader.read (pandas/parser.c:7988)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_low_memory (pandas/parser.c:8244)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_rows (pandas/parser.c:8970)()
#
# pandas/parser.pyx in pandas.parser.TextReader._tokenize_rows (pandas/parser.c:8838)()
#
# pandas/parser.pyx in pandas.parser.raise_parser_error (pandas/parser.c:22649)()
#
# CParserError: Error tokenizing data. C error: Expected 1 fields in line 5, saw 2

# %%
# make a velocity array with the correspoding length and delta v
v_flat = np.arange(v.size*num_boxes)*diffv

# determine the wavelength of Lyman alpha line:
lambda_alpha = lyman_lambda(2)

# make the lists into numpy arrays
t_list = np.array(t_list)
nHI = np.array(nHI)

# find the wavelength where the line starts in v
n = np.arange(2,len(f_1n)+2)
lambda_n = lyman_lambda(n)

#determine the delta v between the Lyman-a and Lyman-n lines:
delta_v_an = c*np.log(lambda_alpha/lambda_n) # km/s

# determine what index the nth line should appear in the v_flat array
N_n = np.zeros_like(delta_v_an, dtype=np.int32)
for i,dv in enumerate(delta_v_an):
    N_n[i] = np.where(abs(v_flat - dv)/diffv < 0.5)[0][0]

# %%
diff_line_list = []
num_lines_array = [50]
num_spectra = len(file_list)
# nHI_list = []
for num_lines in num_lines_array:
    tau_final = []
    nHI_final = []
    for i in range(num_spectra):

        # choose 50 random boxes from the 2000 different boxes
        randos = np.random.randint(len(file_list[::step]), size=num_boxes)
        t_sublist = t_list[randos,:]

        # flatten the array of opacity
        tau_flat = np.array(t_sublist).flatten()
        
        
        # choose 50 random boxes from the 2000/step different boxes
        n_sublist = nHI[randos,:]

        # flatten the array of density
        nHI_flat = np.array(n_sublist).flatten()

        # make a deep copy of the flattened opacity array so it doesnt get changed below
        # when we +=
        tau_n = np.zeros_like(tau_flat)
        # nHI_n = np.zeros_like(nHI_flat)

        # loop through the lyman series
        for i,n in enumerate(N_n):
            # sum the opacites at the point in the velocity array where they occur
            # f_1n[1] = Lyman beta line
            tau_n[n:] +=  tau_flat[:len(tau_n[n:])]*f_1n[i]
            

        tau_final.append(tau_n)
        nHI_final.append(nHI_flat)
    tau_final = np.array(tau_final)
    nHI_final = np.array(nHI_final)
    tau_final = tau_final.sum(0)
    nHI_final = nHI_final.sum(0)
    diff_line_list.append(tau_final/num_spectra)
    nHI_final = nHI_final/num_spectra

# %%
fig, ax = plt.subplots(figsize=(12,6))

for num,d in enumerate(diff_line_list):
    ax.plot(v_flat, flux(d), label='{} lines'.format(num_lines_array[num]))
ax.legend()
plt.show()

# %% [markdown]
# Plotting $n_{HI}$. Averaged vs 50 random boxes.

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.semilogy(v_flat, nHI_flat)
ax.semilogy(v_flat, nHI_final)
ax.set_xlim(0,100000)
# Out:
# (0, 100000)

# %% [markdown]
# $$ \frac{1 + z_{max}}{1 + z_{obs}} = \frac{\nu_i}{v_{obs}} $$

# %%
vLL = c * (700/912 + 1)
print vLL

# proper_d = (v_flat/70.)*(1 - (1+q0)/2 * v_flat/c)
def proper_d(z1, z2, omega_m):
    H0 = 70 # km/s/Mpc
    return (1/(H0*np.sqrt(omega_m)))*(1/np.sqrt(1+z1) - 1/np.sqrt(1+z2))
    

NHI = nHI_flat*proper_d(v)

spectrum = np.copy(diff_line_list[0])
Ly_continuum_condition = np.where(spectrum <  vLL)

spectrum[Ly_continuum_condition] = NHI*(1 + spectrum[Ly_continuum_condition]/c)**3 * sigma0

plt.plot(v_flat, spectrum)
# Out:
# 529896.318307
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ba932a5677f9> in <module>()
#       8
#       9
# ---> 10 NHI = nHI_flat*proper_d
#      11
#      12 spectrum = np.copy(diff_line_list[0])
#
# TypeError: unsupported operand type(s) for *: 'float' and 'function'

# %%
fig, ax = plt.subplots(figsize=(12,6))

for num,d in enumerate(diff_line_list):
    ax.plot(lam_obs(v_flat,700), flux(d), label='{} lines'.format(num_lines_array[num]))
ax.legend()
plt.show()

ax.set_xlim(700,1216)
ax.set_xlabel(r'$\lambda(1+z)$ $[\AA]$')
ax.set_ylabel(r'$e^{-\tau}$')
ax.legend()

plt.show()

# %% [markdown]
# resolution $= R = lambda/deltalambda =c/deltav  deltav(accross the cell) = c/R$
#
#
# $$R = c / \Delta v = \lambda / \Delta \lambda   = 149089.2$$
#
# $$\sigma = (R_{sdss}/R)*\delta v$$

# %%
R = c/np.diff(v_flat)[0]
print "R = ",R

# %%
from astropy.convolution import Gaussian1DKernel, convolve

# %%
def plot_spec(x,y):
    ax.plot(lam_obs(x,1216),flux(y), alpha=0.5)
    ax.set_xlim(700,1216)
    ax.set_xlabel(r'$\lambda(1+z)$ $[\AA]$')
    ax.set_ylabel(r'$e^{-\tau}$')

# %%
# Create kernel
dv_cell = 10.2679380093

R_sdss = 2000. # sdss resolution

#compute the stdev for the gaussian smoothing
sigma = (R_sdss/R)*diffv

g = Gaussian1DKernel(stddev=sigma)

x = v_flat

# Convolve data
z = convolve(diff_line_list[0], g , boundary='extend', normalize_kernel=True)

fig, ax = plt.subplots(figsize=(12,6))
ax.plot(lam_obs(x,1216), flux(z), alpha=0.5)

ax.set_xlim(912,1216)
ax.set_xlabel(r'$\lambda(1+z)$ $[\AA]$')
ax.set_ylabel(r'$e^{-\tau}$')
ax.set_title(r'spectrum convolved with a gaussian to $R = R_{sdss}$')
# plt.xlim(912,1216)
plt.show()

# %% [markdown]
# Need to add the average step increase.

# %% [markdown]
# $ \langle F_n \rangle = \langle e^{-\tau_{\nu}} \rangle $
#
# $ \tau^{n}_{eff} = - log \langle F_n \rangle $
#
# $ \tau^{tot}_{eff} = \Sigma \tau^{n}_{eff} $
#
# Then plot:
#
# $e^{\tau^{tot}_{eff}}$

# %%
ave_Fn = []
tn_eff = []
for f in f_1n:
    ave_Fn.append(np.mean(flux(tau_HILya*f)))
    tn_eff.append(-np.log(np.mean(flux(tau_HILya*f))))

# %%
print len(tn_eff)
print lambda_n.shape

# %%
fig, ax = plt.subplots(figsize=(12,6))

plot_spec(x,z)
ax.step(lambda_n, np.exp(-np.cumsum(tn_eff)))
ax.set_title(r'$R_{2000}$ spectra vs $e^{\tau^{tot}_{eff}}$')
plt.show()

# %% [markdown]
# ## Add continuum opacity
#
#
# $\tau = \sigma n_H L$
#
# where $L$ is the pixel size

# %% [markdown]
# $ \Delta \tau_m = \sigma(v_m) n_{HI} L $
#
# where
#
# $ \sigma(v_m) =  \sigma_0 \Big(\frac{\lambda_{obs}}{\lambda_{emit}}\Big)^3 =
#     \sigma_0 (1 + z)^3 $

# %%
def one_plus_z(v):
    c = const.c.to(u.km / u.s).value
    return np.sqrt(1+v/c)/np.sqrt(1-v/c)

def sigma_bf(v):
    c = const.c.to(u.km / u.s).value
    oneplusz = np.sqrt(1+v/c)/np.sqrt(1-v/c)
    return 6.30e-18*(oneplusz)**(3)

# %%
plt.plot(v_flat, sigma_bf(v_flat))

# %%
h = 0.7
L = 2.50e+04*u.kpc
L_physical = (L*h).to(u.cm).value
print L_physical

delta_tau_m = sigma_bf(v_flat)*nHI_flat*L_physical*50
plt.plot(delta_tau_m)

# %%
tau_lyman = np.zeros_like(diff_line_list[0])
LymanLimit = np.where(True)

print lyman_lambda(10000000)
dv = np.log(lyman_lambda(2)/lyman_lambda(1000))
print dv
print np.where(abs(v_flat - dv)/diffv < 0.5)[0][0]

tau_lyman[:N_n[-1]] = diff_line_list[0][:N_n[-1]]

# %%
# make a velocity array with the correspoding length and delta v
v_flat = np.arange(v.size*num_boxes)*diffv

# determine the wavelength of Lyman alpha line:
lambda_alpha = lyman_lambda(2)

# make the lists into numpy arrays
t_list = np.array(t_list)
nHI = np.array(nHI)

# find the wavelength where the line starts in v
n = np.arange(2,len(f_1n)+2)
lambda_n = lyman_lambda(n)

#determine the delta v between the Lyman-a and Lyman-n lines:
delta_v_an = c*np.log(lambda_alpha/lambda_n) # km/s

# determine what index the nth line should appear in the v_flat array
N_n = np.zeros_like(delta_v_an, dtype=np.int32)
for i,dv in enumerate(delta_v_an):
    N_n[i] = np.where(abs(v_flat - dv)/diffv < 0.5)[0][0]

# %% [markdown]
# $$ N(n) = \sum_{i=0}^{n} n_{HI}L\Big(\frac{1+z_{n}}{1+z_{0}}\Big)^{-3} $$
#
# $$ \tau_n = N(n)\Big(\frac{\nu_n}{\nu_0}\Big)^{-3}\sigma_0 $$
#
# where
#
# $$ 1 + z = \frac{\sqrt{1+v/c}}{\sqrt{1-v/c}} $$
#
# and
#
# $$ 1 + z_n = \frac{\sqrt{1+v_n/c}}{\sqrt{1-v_n/c}} $$

# %%
nHI_flat = np.ones_like(nHI_flat)*1e-5
col_dens = nHI_flat*L_physical*50*(one_plus_z(v_flat)/one_plus_z(v_flat[0]))**(-3)

# %%
sigma0 = 6.30e-18
tau_continuum = col_dens*sigma0*(one_plus_z(v_flat))**3

# %%
plt.plot(col_dens)
#plt.plot(nHI_flat)

# %%
lambda_n[-1]

# %%
N_n[-1]

# %%
v_flat[N_n[-1]]

# %%
t_cont = np.zeros_like(tau_continuum)
t_lyman = np.zeros_like(diff_line_list[0])

t_cont[N_n[-1]:] = tau_continuum[N_n[-1]:]
t_lyman[:N_n[-1]] = diff_line_list[0][:N_n[-1]]

# %%
plt.plot(v_flat, tau_continuum)
plt.plot(v_flat, diff_line_list[0])

# %%
tau_tot = t_cont + t_lyman

# %%
fig, ax = plt.subplots(figsize=(12,6))

plot_spec(v_flat,tau_tot)

# %%
v_LL = c*(912/1216 - 1)

# %%
v_LL

# %%
lam_obs(abs(v_LL),1216)
